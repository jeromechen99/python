# %%
spam_amount = 0
print(spam_amount)

# Ordering Spam, egg, Spam, Spam, bacon and Spam (4 more servings of Spam)
spam_amount = spam_amount + 4

if spam_amount > 0:
    print("But I don't want ANY spam!")

viking_song = "Spam " * spam_amount
print(viking_song)

type(spam_amount)
# Out:
# 0
# But I don't want ANY spam!
# Spam Spam Spam Spam
# int

# %%
hat_height_cm = 25
my_height_cm = 190
# How tall am I, in meters, when wearing my hat?
total_height_meters = hat_height_cm + my_height_cm / 100
print("Height in meters =", total_height_meters, "?")
# Out:
# Height in meters = 26.9 ?

# %%
max(1,33, 230)
# Out:
# 230

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ---------
# aiohttp                            3.6.2
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# asn1crypto                         1.0.1
# astroid                            2.3.1
# astropy                            3.2.2
# async-timeout                      3.0.1
# atomicwrites                       1.3.0
# attrs                              19.2.0
# awscli                             1.16.304
# Babel                              2.7.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.6.1
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.8.0
# bitarray                           1.0.1
# bkcharts                           0.2
# bleach                             3.1.0
# bokeh                              1.3.4
# boto                               2.49.0
# botocore                           1.13.40
# Bottleneck                         1.2.1
# certifi                            2019.9.11
# cffi                               1.12.3
# chardet                            3.0.4
# Click                              7.0
# cloudpickle                        1.2.2
# clyent                             1.2.2
# colorama                           0.4.1
# conda                              4.8.2
# conda-build                        3.18.9
# conda-package-handling             1.6.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0
# cryptography                       2.7
# cx-Oracle                          7.3.0
# cycler                             0.10.0
# Cython                             0.29.13
# cytoolz                            0.10.0
# dask                               2.5.2
# decorator                          4.4.0
# defusedxml                         0.6.0
# distributed                        2.5.2
# docutils                           0.15.2
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# Flask                              1.1.1
# fsspec                             0.5.2
# future                             0.18.2
# gevent                             1.4.0
# glob2                              0.7
# gmpy2                              2.0.8
# greenlet                           0.4.15
# h5py                               2.9.0
# HeapDict                           1.0.1
# html5lib                           1.0.1
# idna                               2.8
# imageio                            2.6.0
# imagesize                          1.1.0
# importlib-metadata                 0.23
# ipykernel                          5.1.2
# ipython                            7.8.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.15.1
# jeepney                            0.4.1
# Jinja2                             2.10.3
# jmespath                           0.9.4
# joblib                             0.13.2
# json5                              0.8.5
# jsonschema                         3.0.2
# jupyter                            1.0.0
# jupyter-client                     5.3.3
# jupyter-console                    6.0.0
# jupyter-core                       4.5.0
# jupyterlab                         1.1.4
# jupyterlab-server                  1.0.6
# kazoo                              2.5.0
# keyring                            18.0.0
# kiwisolver                         1.1.0
# lazy-object-proxy                  1.4.2
# libarchive-c                       2.8
# lief                               0.9.0
# llvmlite                           0.29.0
# locket                             0.2.0
# lxml                               4.4.1
# MarkupSafe                         1.1.1
# matplotlib                         3.1.1
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.0.14
# mkl-random                         1.1.0
# mkl-service                        2.3.0
# mock                               3.0.5
# more-itertools                     7.2.0
# mpmath                             1.1.0
# msgpack                            0.6.1
# multidict                          4.7.5
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbconvert                          5.6.0
# nbformat                           4.4.0
# networkx                           2.3
# nltk                               3.4.5
# nose                               1.3.7
# notebook                           6.0.1
# numba                              0.45.1
# numexpr                            2.7.0
# numpy                              1.17.2
# numpydoc                           0.9.1
# olefile                            0.46
# openpyxl                           3.0.0
# packaging                          19.2
# pandas                             0.25.1
# pandocfilters                      1.4.2
# parso                              0.5.1
# partd                              1.0.0
# path.py                            12.0.1
# pathlib2                           2.3.5
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.7.0
# pickleshare                        0.7.5
# Pillow                             6.2.0
# pip                                19.2.3
# pkginfo                            1.5.0.1
# pluggy                             0.13.0
# ply                                3.11
# prometheus-client                  0.7.1
# prompt-toolkit                     2.0.10
# psutil                             5.6.3
# ptyprocess                         0.6.0
# py                                 1.8.0
# pyasn1                             0.4.8
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.3
# pyee                               7.0.1
# pyflakes                           2.1.1
# Pygments                           2.4.2
# pykafka                            2.8.0
# pylint                             2.4.2
# pyodbc                             4.0.27
# pyOpenSSL                          19.0.0
# pyparsing                          2.4.2
# pyrsistent                         0.15.4
# PySocks                            1.7.1
# pytest                             5.2.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.5.0
# pytest-doctestplus                 0.4.0
# pytest-openfiles                   0.4.0
# pytest-remotedata                  0.3.2
# python-dateutil                    2.8.0
# pytz                               2019.3
# PyWavelets                         1.0.3
# PyYAML                             5.1.2
# pyzmq                              18.1.0
# QtAwesome                          0.6.0
# qtconsole                          4.5.5
# QtPy                               1.9.0
# requests                           2.22.0
# rope                               0.14.0
# rsa                                3.4.2
# ruamel-yaml                        0.15.46
# s3transfer                         0.2.1
# scikit-image                       0.15.0
# scikit-learn                       0.21.3
# scipy                              1.3.1
# seaborn                            0.9.0
# SecretStorage                      3.1.1
# Send2Trash                         1.5.0
# setuptools                         41.4.0
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.12.0
# slackclient                        2.5.0
# slackeventsapi                     2.1.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.9.3
# Sphinx                             2.2.0
# sphinxcontrib-applehelp            1.0.1
# sphinxcontrib-devhelp              1.0.1
# sphinxcontrib-htmlhelp             1.0.2
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.2
# sphinxcontrib-serializinghtml      1.1.3
# sphinxcontrib-websupport           1.1.2
# spyder                             3.3.6
# spyder-kernels                     0.5.2
# SQLAlchemy                         1.3.9
# statsmodels                        0.10.1
# sympy                              1.4
# tables                             3.5.2
# tabulate                           0.8.9
# tblib                              1.4.0
# terminado                          0.8.2
# testpath                           0.4.2
# toolz                              0.10.0
# tornado                            6.0.3
# tqdm                               4.36.1
# traitlets                          4.3.3
# unicodecsv                         0.14.1
# urllib3                            1.24.2
# wcwidth                            0.1.7
# webencodings                       0.5.1
# Werkzeug                           0.16.0
# wheel                              0.33.6
# widgetsnbextension                 3.5.1
# wrapt                              1.11.2
# wurlitzer                          1.0.3
# xlrd                               1.2.0
# XlsxWriter                         1.2.1
# xlwt                               1.3.0
# yarl                               1.4.2
# zict                               1.0.0
# zipp                               0.6.0

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /home/rochen/anaconda3/lib/python3.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# WARNING: AstropyDeprecationWarning: astropy.utils.compat.futures is now deprecated - use concurrent.futures instead [astropy.utils.compat.futures]
# /home/rochen/anaconda3/lib/python3.7/site-packages/nltk/twitter/__init__.py:22: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   "The twython library has not been installed. "
# DEBUG:pip._internal.vcs.versioncontrol:Registered VCS backend: bzr
# DEBUG:pip._internal.vcs.versioncontrol:Registered VCS backend: git
# DEBUG:pip._internal.vcs.versioncontrol:Registered VCS backend: hg
# DEBUG:pip._internal.vcs.versioncontrol:Registered VCS backend: svn
# INFO:pykafka.topic:Could not load pykafka.rdkafka extension.
# DEBUG:pykafka.topic:Traceback:
# Traceback (most recent call last):
#   File "/home/rochen/anaconda3/lib/python3.7/site-packages/pykafka/topic.py", line 43, in <module>
#     from . import rdkafka
#   File "/home/rochen/anaconda3/lib/python3.7/site-packages/pykafka/rdkafka/__init__.py", line 1, in <module>
#     from .producer import RdKafkaProducer
#   File "/home/rochen/anaconda3/lib/python3.7/site-packages/pykafka/rdkafka/producer.py", line 7, in <module>
#     from . import _rd_kafka
# ImportError: cannot import name '_rd_kafka' from 'pykafka.rdkafka' (/home/rochen/anaconda3/lib/python3.7/site-packages/pykafka/rdkafka/__init__.py)
# /home/rochen/anaconda3/lib/python3.7/site-packages/skimage/novice/__init__.py:103: UserWarning: The `skimage.novice` module was deprecated in version 0.14. It will be removed in 0.16.
#   warnings.warn("The `skimage.novice` module was deprecated in version 0.14. "
# /home/rochen/anaconda3/lib/python3.7/site-packages/skimage/viewer/utils/core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "
# /home/rochen/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/rochen/anaconda3/lib/python3.7/site-packages/qtawesome/iconic_font.py:301: UserWarning: You need to have a running QApplication to use QtAwesome!
#   warnings.warn("You need to have a running "
# /home/rochen/anaconda3/lib/python3.7/pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# Crypto              brain_numpy_core_function_base jupyter             rmagic
# Cython              brain_numpy_core_multiarray jupyter_client      rope
# IPython             brain_numpy_core_numeric jupyter_console     rsa
# OpenSSL             brain_numpy_core_numerictypes jupyter_core        ruamel_yaml
# PIL                 brain_numpy_core_umath jupyterlab          runJediLanguageServer
# PyQt5               brain_numpy_ndarray jupyterlab_server   runpy
# __future__          brain_numpy_random_mtrand kazoo               s3transfer
# _abc                brain_numpy_utils   keyring             sched
# _ast                brain_pkg_resources keyword             scipy
# _asyncio            brain_pytest        kiwisolver          scripts
# _bisect             brain_qt            lazy_object_proxy   seaborn
# _blake2             brain_random        lib2to3             secrets
# _bootlocale         brain_re            libarchive          secretstorage
# _bz2                brain_six           libfuturize         select
# _cffi_backend       brain_ssl           libpasteurize       selectors
# _codecs             brain_subprocess    lief                send2trash
# _codecs_cn          brain_threading     linecache           setuptools
# _codecs_hk          brain_typing        llvmlite            shell_exec
# _codecs_iso2022     brain_uuid          locale              shelve
# _codecs_jp          bs4                 locket              shlex
# _codecs_kr          builtins            logging             shutil
# _codecs_tw          bz2                 lxml                signal
# _collections        cProfile            lzma                simplegeneric
# _collections_abc    calendar            macpath             singledispatch
# _compat_pickle      certifi             mailbox             singledispatch_helpers
# _compression        cffi                mailcap             sip
# _contextvars        cgi                 markupsafe          sipconfig
# _crypt              cgitb               marshal             sipdistutils
# _csv                chardet             math                site
# _ctypes             chunk               matplotlib          six
# _ctypes_test        click               mccabe              skimage
# _curses             cloudpickle         mimetypes           sklearn
# _curses_panel       clyent              mistune             slack
# _datetime           cmath               mkl                 slackeventsapi
# _decimal            cmd                 mkl_fft             smtpd
# _dummy_thread       code                mkl_random          smtplib
# _elementtree        codecs              mmap                sndhdr
# _functools          codeop              mock                snowballstemmer
# _hashlib            collections         modulefinder        socket
# _heapq              colorama            more_itertools      socketserver
# _imp                colorsys            mpmath              socks
# _io                 compileall          msgpack             sockshandler
# _json               completion          multidict           sortedcollections
# _locale             concurrent          multipledispatch    sortedcontainers
# _lsprof             conda               multiprocessing     soupsieve
# _lzma               conda_build         navigator_updater   sphinx
# _markupbase         conda_env           nbconvert           sphinxcontrib
# _md5                conda_package_handling nbformat            spwd
# _multibytecodec     conda_verify        netrc               spyder
# _multiprocessing    configparser        networkx            spyder_breakpoints
# _opcode             contextlib          nis                 spyder_io_dcm
# _operator           contextlib2         nltk                spyder_io_hdf5
# _osx_support        contextvars         nntplib             spyder_kernels
# _pickle             copy                normalizeForInterpreter spyder_profiler
# _posixsubprocess    copyreg             normalizeSelection  spyder_pylint
# _py_abc             crypt               nose                sqlalchemy
# _pydecimal          cryptography        notebook            sqlite3
# _pyio               csv                 ntpath              sre_compile
# _pylief             ctypes              nturl2path          sre_constants
# _pyrsistent_version curl                numba               sre_parse
# _pytest             curses              numbers             ssl
# _queue              cx_Oracle           numexpr             stat
# _random             cycler              numpy               statistics
# _sha1               cython              numpydoc            statsmodels
# _sha256             cythonmagic         olefile             storemagic
# _sha3               cytoolz             opcode              string
# _sha512             dask                openpyxl            stringprep
# _signal             dataclasses         operator            struct
# _sitebuiltins       datetime            optparse            subprocess
# _socket             dateutil            os                  sunau
# _sqlite3            dbm                 ossaudiodev         symbol
# _sre                decimal             packaging           symbolProvider
# _ssl                decorator           pandas              sympy
# _stat               defusedxml          pandocfilters       sympyprinting
# _string             difflib             parser              symtable
# _strptime           dis                 parso               sys
# _struct             distributed         partd               sysconfig
# _symtable           distutils           past                syslog
# _sysconfigdata_i686_conda_cos6_linux_gnu doctest             path                tables
# _sysconfigdata_m_linux_x86_64-linux-gnu docutils            pathlib             tabnanny
# _sysconfigdata_powerpc64le_conda_cos7_linux_gnu dummy_threading     pathlib2            tabulate
# _sysconfigdata_x86_64_apple_darwin13_4_0 easy_install        patsy               tarfile
# _sysconfigdata_x86_64_conda_cos6_linux_gnu email               pdb                 tblib
# _testbuffer         encodings           pep8                telnetlib
# _testcapi           ensurepip           pexpect             tempfile
# _testimportmultiple entrypoints         pickle              terminado
# _testmultiphase     enum                pickleshare         termios
# _thread             errno               pickletools         test
# _threading_local    et_xmlfile          pip                 test_data
# _tkinter            fastcache           pipes               test_pycosat
# _tracemalloc        faulthandler        pkg_resources       testlauncher
# _warnings           fcntl               pkginfo             testpath
# _weakref            filecmp             pkgutil             tests
# _weakrefset         fileinput           platform            textwrap
# _xxtestfuzz         filelock            plistlib            this
# _yaml               flask               pluggy              threading
# abc                 fnmatch             ply                 time
# aggregateTestResults formatter           poplib              timeit
# aifc                fractions           posix               tkinter
# aiohttp             fsspec              posixpath           tlz
# alabaster           ftplib              pprint              token
# anaconda_navigator  functools           printEnvVariables   tokenize
# anaconda_project    future              printEnvVariablesToFile toolz
# antigravity         gc                  printJupyWidgetEntryPoints tornado
# argparse            genericpath         printJupyterDataDir tqdm
# array               get-pip             profile             trace
# asn1crypto          getopt              prometheus_client   traceback
# ast                 getpass             prompt_toolkit      tracemalloc
# astroid             gettext             pstats              traitlets
# astropy             gevent              psutil              tty
# async_timeout       glob                pty                 turtle
# asynchat            glob2               ptyprocess          turtledemo
# asyncio             gmpy2               pvectorc            types
# asyncore            greenlet            pwd                 typing
# atexit              grp                 py                  unicodecsv
# atomicwrites        gzip                py_compile          unicodedata
# attr                h5py                pyasn1              unittest
# audioop             hashlib             pyclbr              urllib
# autoreload          heapdict            pycodestyle         urllib3
# awscli              heapq               pycosat             uu
# babel               hmac                pycparser           uuid
# backcall            html                pycurl              venv
# backports           html5lib            pydoc               visualstudio_py_testlauncher
# base64              http                pydoc_data          vscode_datascience_helpers
# bdb                 idlelib             pyee                warnings
# binascii            idna                pyexpat             wave
# binhex              imageio             pyflakes            wcwidth
# binstar_client      imagesize           pygments            weakref
# bisect              imaplib             pykafka             webbrowser
# bitarray            imghdr              pylab               webencodings
# bkcharts            imp                 pylint              werkzeug
# bleach              importlib           pyls_jsonrpc        wheel
# bokeh               importlib_metadata  pyodbc              widgetsnbextension
# boto                inspect             pyparsing           wrapt
# botocore            install_debugpy     pyrsistent          wsgiref
# bottleneck          interpreterInfo     pytest              wurlitzer
# brain_argparse      io                  pytest_arraydiff    xdrlib
# brain_attrs         ipaddress           pytest_doctestplus  xlrd
# brain_builtin_inference ipykernel           pytest_openfiles    xlsxwriter
# brain_collections   ipykernel_launcher  pytest_remotedata   xlwt
# brain_crypt         ipython_genutils    pytz                xml
# brain_curses        ipywidgets          pywt                xmlrpc
# brain_dataclasses   isort               pyximport           xxlimited
# brain_dateutil      isympy              qtawesome           xxsubtype
# brain_fstrings      itertools           qtconsole           yaml
# brain_functools     itsdangerous        qtpy                yarl
# brain_gi            jdcal               queue               zict
# brain_hashlib       jedi                quopri              zipapp
# brain_http          jeepney             random              zipfile
# brain_io            jinja2              re                  zipimport
# brain_mechanize     jmespath            readline            zipp
# brain_multiprocessing joblib              reprlib             zlib
# brain_namedtuple_enum json                requests            zmq
# brain_nose          json5               resource
# brain_numpy_core_fromnumeric jsonschema          rlcompleter
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
#
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
# !pip freeze
# Out:
# aiohttp==3.6.2
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.3
# asn1crypto==1.0.1
# astroid==2.3.1
# astropy==3.2.2
# async-timeout==3.0.1
# atomicwrites==1.3.0
# attrs==19.2.0
# awscli==1.16.304
# Babel==2.7.0
# backcall==0.1.0
# backports.functools-lru-cache==1.6.1
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.8.0
# bitarray==1.0.1
# bkcharts==0.2
# bleach==3.1.0
# bokeh==1.3.4
# boto==2.49.0
# botocore==1.13.40
# Bottleneck==1.2.1
# certifi==2019.9.11
# cffi==1.12.3
# chardet==3.0.4
# Click==7.0
# cloudpickle==1.2.2
# clyent==1.2.2
# colorama==0.4.1
# conda==4.8.2
# conda-build==3.18.9
# conda-package-handling==1.6.0
# conda-verify==3.4.2
# contextlib2==0.6.0
# cryptography==2.7
# cx-Oracle==7.3.0
# cycler==0.10.0
# Cython==0.29.13
# cytoolz==0.10.0
# dask==2.5.2
# decorator==4.4.0
# defusedxml==0.6.0
# distributed==2.5.2
# docutils==0.15.2
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastcache==1.1.0
# filelock==3.0.12
# Flask==1.1.1
# fsspec==0.5.2
# future==0.18.2
# gevent==1.4.0
# glob2==0.7
# gmpy2==2.0.8
# greenlet==0.4.15
# h5py==2.9.0
# HeapDict==1.0.1
# html5lib==1.0.1
# idna==2.8
# imageio==2.6.0
# imagesize==1.1.0
# importlib-metadata==0.23
# ipykernel==5.1.2
# ipython==7.8.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.15.1
# jeepney==0.4.1
# Jinja2==2.10.3
# jmespath==0.9.4
# joblib==0.13.2
# json5==0.8.5
# jsonschema==3.0.2
# jupyter==1.0.0
# jupyter-client==5.3.3
# jupyter-console==6.0.0
# jupyter-core==4.5.0
# jupyterlab==1.1.4
# jupyterlab-server==1.0.6
# kazoo==2.5.0
# keyring==18.0.0
# kiwisolver==1.1.0
# lazy-object-proxy==1.4.2
# libarchive-c==2.8
# lief==0.9.0
# llvmlite==0.29.0
# locket==0.2.0
# lxml==4.4.1
# MarkupSafe==1.1.1
# matplotlib==3.1.1
# mccabe==0.6.1
# mistune==0.8.4
# mkl-fft==1.0.14
# mkl-random==1.1.0
# mkl-service==2.3.0
# mock==3.0.5
# more-itertools==7.2.0
# mpmath==1.1.0
# msgpack==0.6.1
# multidict==4.7.5
# multipledispatch==0.6.0
# navigator-updater==0.2.1
# nbconvert==5.6.0
# nbformat==4.4.0
# networkx==2.3
# nltk==3.4.5
# nose==1.3.7
# notebook==6.0.1
# numba==0.45.1
# numexpr==2.7.0
# numpy==1.17.2
# numpydoc==0.9.1
# olefile==0.46
# openpyxl==3.0.0
# packaging==19.2
# pandas==0.25.1
# pandocfilters==1.4.2
# parso==0.5.1
# partd==1.0.0
# path.py==12.0.1
# pathlib2==2.3.5
# patsy==0.5.1
# pep8==1.7.1
# pexpect==4.7.0
# pickleshare==0.7.5
# Pillow==6.2.0
# pkginfo==1.5.0.1
# pluggy==0.13.0
# ply==3.11
# prometheus-client==0.7.1
# prompt-toolkit==2.0.10
# psutil==5.6.3
# ptyprocess==0.6.0
# py==1.8.0
# pyasn1==0.4.8
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.3
# pyee==7.0.1
# pyflakes==2.1.1
# Pygments==2.4.2
# pykafka==2.8.0
# pylint==2.4.2
# pyodbc==4.0.27
# pyOpenSSL==19.0.0
# pyparsing==2.4.2
# pyrsistent==0.15.4
# PySocks==1.7.1
# pytest==5.2.1
# pytest-arraydiff==0.3
# pytest-astropy==0.5.0
# pytest-doctestplus==0.4.0
# pytest-openfiles==0.4.0
# pytest-remotedata==0.3.2
# python-dateutil==2.8.0
# pytz==2019.3
# PyWavelets==1.0.3
# PyYAML==5.1.2
# pyzmq==18.1.0
# QtAwesome==0.6.0
# qtconsole==4.5.5
# QtPy==1.9.0
# requests==2.22.0
# rope==0.14.0
# rsa==3.4.2
# ruamel-yaml==0.15.46
# s3transfer==0.2.1
# scikit-image==0.15.0
# scikit-learn==0.21.3
# scipy==1.3.1
# seaborn==0.9.0
# SecretStorage==3.1.1
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.12.0
# slackclient==2.5.0
# slackeventsapi==2.1.0
# snowballstemmer==2.0.0
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# soupsieve==1.9.3
# Sphinx==2.2.0
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.1.2
# spyder==3.3.6
# spyder-kernels==0.5.2
# SQLAlchemy==1.3.9
# statsmodels==0.10.1
# sympy==1.4
# tables==3.5.2
# tabulate==0.8.9
# tblib==1.4.0
# terminado==0.8.2
# testpath==0.4.2
# toolz==0.10.0
# tornado==6.0.3
# tqdm==4.36.1
# traitlets==4.3.3
# unicodecsv==0.14.1
# urllib3==1.24.2
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.16.0
# widgetsnbextension==3.5.1
# wrapt==1.11.2
# wurlitzer==1.0.3
# xlrd==1.2.0
# XlsxWriter==1.2.1
# xlwt==1.3.0
# yarl==1.4.2
# zict==1.0.0
# zipp==0.6.0

# %%
# !pip install git+https://github.com/Kaggle/learntools.git
# Out:
# Collecting git+https://github.com/Kaggle/learntools.git
#   Cloning https://github.com/Kaggle/learntools.git to /tmp/pip-req-build-lnd3g_42
#   Running command git clone -q https://github.com/Kaggle/learntools.git /tmp/pip-req-build-lnd3g_42
# Building wheels for collected packages: learntools
#   Building wheel for learntools (setup.py) ... done
#   Created wheel for learntools: filename=learntools-0.3.4-cp37-none-any.whl size=267770 sha256=5c6849612792701ecdd60d58b3b045083178fc601158ab18a13d30b774f53d0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ti3r4olk/wheels/be/e6/c1/ea4ee69de95f8f0e627b7a26125e8348391eaf84cb7015e68f
# Successfully built learntools
# Installing collected packages: learntools
# Successfully installed learntools-0.3.4
